# %%
import psycopg2
import pandas as pd

conexao = psycopg2.connect(host="kesavan.db.elephantsql.com", database="cjwdogrw", user="cjwdogrw", password="acihzKCpPs16aX1MGNmlYqY1OV--19Q6")
cursor = conexao.cursor()

# %%
cursor.execute("""SELECT * FROM pedido
                  WHERE data_hora_entrega_prevista > '2022-05-23' """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select1 = pd.DataFrame(data=data,columns = colunas) 

select1
# Out:
#    cod_pedido   data_hora_criacao data_hora_entrega_prevista  preco_total  \
# 0           3 2022-05-19 10:11:00        2022-05-23 10:11:00        150.0
# 1           4 2022-05-20 10:11:00        2022-05-24 10:11:00        100.0
# 2           5 2022-05-21 10:11:00        2022-05-25 10:11:00         50.0
#
#    fk_cod_tipo_pagamento  fk_cod_cliente
# 0                      3               3
# 1                      3               4
# 2                      2               5

# %%
cursor.execute("""SELECT * FROM pedido
                  WHERE preco_total < 100""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select2 = pd.DataFrame(data=data,columns = colunas) 

select2
# Out:
#    cod_pedido   data_hora_criacao data_hora_entrega_prevista  preco_total  \
# 0           2 2022-05-18 10:11:00        2022-05-22 10:11:00         50.0
# 1           5 2022-05-21 10:11:00        2022-05-25 10:11:00         50.0
#
#    fk_cod_tipo_pagamento  fk_cod_cliente
# 0                      5               2
# 1                      2               5

# %%
cursor.execute("""SELECT * FROM produto
                  WHERE preco = 50""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select3 = pd.DataFrame(data=data,columns = colunas) 

select3
# Out:
#    cod_produto                 nome  preco
# 0            1  Cento de brigadeiro   50.0
# 1            3    Cento de beijinho   50.0

# %%
cursor.execute("""SELECT * FROM preparo
                  WHERE fk_cod_produto = 2""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select4 = pd.DataFrame(data=data,columns = colunas) 

select4
# Out:
#    cod_preparo                                    descricao_passo  ordem  \
# 0            1      Bata todos os ingredientes no liquidificador.      1
# 1            2         Coloque em uma forma untada e enfarinhada.      2
# 2            3  Leve ao forno preaquecido e deixe assar, por c...      3
#
#    fk_cod_produto
# 0               2
# 1               2
# 2               2

# %%
conexao.close();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0915bee567e1> in <module>()
# ----> 1 conexao.close();
#
# NameError: name 'conexao' is not defined
