# %%
import psycopg2
import pandas as pd

conexao = psycopg2.connect(host="kesavan.db.elephantsql.com", database="cjwdogrw", user="cjwdogrw", password="acihzKCpPs16aX1MGNmlYqY1OV--19Q6")
cursor = conexao.cursor()
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ##### a) Criar 5 consultas que envolvam os operadores lógicos AND, OR e Not

# %%
cursor.execute("""SELECT * FROM cliente 
                  WHERE nome = 'Camila Volponi' OR nome = 'Vitor da Silva' """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select1 = pd.DataFrame(data=data,columns = colunas) 

select1
# Out:
#    cod_cliente            nome
# 0            2  Camila Volponi
# 1            4  Vitor da Silva

# %%
cursor.execute("""SELECT * FROM produto
                  WHERE (NOT preco=50) """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select2 = pd.DataFrame(data=data,columns = colunas) 

select2
# Out:
#    cod_produto               nome  preco
# 0            2       Bolo de fuba   30.0
# 1            4  Bolo de chocolate   30.0
# 2            5              Pudim   20.0

# %%
cursor.execute("""SELECT * FROM pedido
                  WHERE (data_hora_criacao>'2022-05-19' AND data_hora_entrega_prevista>'2022-05-23')""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select3 = pd.DataFrame(data=data,columns = colunas) 

select3
# Out:
#    cod_pedido   data_hora_criacao data_hora_entrega_prevista  preco_total  \
# 0           3 2022-05-19 10:11:00        2022-05-23 10:11:00        150.0
# 1           4 2022-05-20 10:11:00        2022-05-24 10:11:00        100.0
# 2           5 2022-05-21 10:11:00        2022-05-25 10:11:00         50.0
#
#    fk_cod_tipo_pagamento  fk_cod_cliente
# 0                      3               3
# 1                      3               4
# 2                      2               5

# %%
cursor.execute("""SELECT * FROM produto_ingrediente
                  WHERE (quantidade>1 AND fk_cod_produto=2) """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select4 = pd.DataFrame(data=data,columns = colunas) 

select4
# Out:
#    cod_prod_ingre  quantidade  fk_cod_produto  fk_cod_ingrediente
# 0               1           3               2                   1
# 1               2           2               2                   2
# 2               3           2               2                   3
# 3               4           3               2                   4

# %%
cursor.execute("""SELECT * FROM pedido_produto
                  WHERE (quantidade>1 OR preco=50)""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select5 = pd.DataFrame(data=data,columns = colunas) 

select5
# Out:
#    cod_ped_prod  quantidade  preco  fk_cod_pedido  fk_cod_produto
# 0             1           1   50.0              2               1
# 1             2           2   50.0              3               3
# 2             3           1   50.0              3               1
# 3             6           1   50.0              1               1
# 4             7           1   50.0              1               3
# 5             8           5   20.0              4               5

# %% [markdown]
# ##### b) Criar no mínimo 3 consultas com operadores aritméticos

# %%
cursor.execute("""SELECT nome, preco, (preco*0.8) AS preco_com_desconto FROM produto""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select6 = pd.DataFrame(data=data,columns = colunas) 

select6
# Out:
#                   nome  preco  preco_com_desconto
# 0  Cento de brigadeiro   50.0                40.0
# 1         Bolo de fuba   30.0                24.0
# 2    Cento de beijinho   50.0                40.0
# 3    Bolo de chocolate   30.0                24.0
# 4                Pudim   20.0                16.0

# %%
cursor.execute("""SELECT cod_ped_prod, quantidade, preco, quantidade*preco AS valor_total_por_produto FROM pedido_produto""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select7 = pd.DataFrame(data=data,columns = colunas) 

select7
# Out:
#    cod_ped_prod  quantidade  preco  valor_total_por_produto
# 0             1           1   50.0                     50.0
# 1             2           2   50.0                    100.0
# 2             3           1   50.0                     50.0
# 3             4           1   30.0                     30.0
# 4             5           1   20.0                     20.0
# 5             6           1   50.0                     50.0
# 6             7           1   50.0                     50.0
# 7             8           5   20.0                    100.0

# %%
cursor.execute("""SELECT cod_ped_prod, quantidade*2 AS quantidade_dobrada, preco*2 AS preco_dobrada FROM pedido_produto
                  WHERE cod_ped_prod=2 """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select8 = pd.DataFrame(data=data,columns = colunas) 

select8
# Out:
#    cod_ped_prod  quantidade_dobrada  preco_dobrada
# 0             2                   4          100.0

# %% [markdown]
# ##### c) Criar no mínimo 3 consultas com operação de renomear nomes de campos ou tabelas

# %%
cursor.execute("""SELECT cod_pedido AS numero_pedido, fk_cod_cliente AS cliente, fk_cod_tipo_pagamento AS pagamento_credito FROM pedido AS pedido_credito
                  WHERE fk_cod_tipo_pagamento=3 """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select9 = pd.DataFrame(data=data,columns = colunas) 

select9
# Out:
#    numero_pedido  cliente  pagamento_credito
# 0              3        3                  3
# 1              4        4                  3

# %%
cursor.execute("""SELECT cod_pedido AS numero_pedido, fk_cod_cliente AS cliente, preco_total AS total_igual_50 FROM pedido 
                  WHERE preco_total=50 """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select10 = pd.DataFrame(data=data,columns = colunas) 

select10
# Out:
#    numero_pedido  cliente  total_igual_50
# 0              2        2            50.0
# 1              5        5            50.0

# %%
cursor.execute("""SELECT cod_produto AS numero_produto, nome AS nome_produto, preco AS preco_abaixo_40 FROM produto
                  WHERE preco<40""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select11 = pd.DataFrame(data=data,columns = colunas) 

select11
# Out:
#    numero_produto       nome_produto  preco_abaixo_40
# 0               2       Bolo de fuba             30.0
# 1               4  Bolo de chocolate             30.0
# 2               5              Pudim             20.0

# %%
conexao.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a86eff45937f> in <module>()
# ----> 1 conexao.close()
#
# NameError: name 'conexao' is not defined
