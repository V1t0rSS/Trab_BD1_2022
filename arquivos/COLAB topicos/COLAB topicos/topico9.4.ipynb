# %%
import psycopg2
import pandas as pd

conexao = psycopg2.connect(host="kesavan.db.elephantsql.com", database="cjwdogrw", user="cjwdogrw", password="acihzKCpPs16aX1MGNmlYqY1OV--19Q6")
cursor = conexao.cursor()

# %% [markdown]
# ####a) Criar outras 5 consultas que envolvam like ou ilike

# %%
cursor.execute("""select * from cliente 
                  where nome like 'M%'; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select1 = pd.DataFrame(data=data,columns = colunas) 

select1
# Out:
#    cod_cliente                  nome
# 0            1       Moises da Silva
# 1            3  Mariazinha Feirreira
# 2            5    Marcelo da Vitória

# %%
cursor.execute("""select * from cliente
                  where nome like '%a'; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select2 = pd.DataFrame(data=data,columns = colunas) 

select2
# Out:
#    cod_cliente                  nome
# 0            1       Moises da Silva
# 1            3  Mariazinha Feirreira
# 2            4        Vitor da Silva
# 3            5    Marcelo da Vitória

# %%
cursor.execute("""select * from cliente
                  where nome ilike '%si%'; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select3 = pd.DataFrame(data=data,columns = colunas) 

select3
# Out:
#    cod_cliente             nome
# 0            1  Moises da Silva
# 1            4   Vitor da Silva

# %%
cursor.execute("""select * from produto 
                  where nome like '_ento%'; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select4 = pd.DataFrame(data=data,columns = colunas) 

select4
# Out:
#    cod_produto                 nome  preco
# 0            1  Cento de brigadeiro   50.0
# 1            3    Cento de beijinho   50.0

# %%
cursor.execute("""select * from produto
                  where nome like '_____d%'; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select5 = pd.DataFrame(data=data,columns = colunas) 

select5
# Out:
#    cod_produto               nome  preco
# 0            2       Bolo de fuba   30.0
# 1            4  Bolo de chocolate   30.0

# %%
cursor.execute("""select * from tipo_pagamento where descricao ilike 'p_%y' """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select6 = pd.DataFrame(data=data,columns = colunas) 

select6
# Out:
#    cod_tipo_pagamento descricao
# 0                   2    PicPay

# %%
cursor.execute("""select * from ingrediente
                  where nome ilike 'f%o' or nome like '%ó' """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select7 = pd.DataFrame(data=data,columns = colunas) 

select7
# Out:
#    cod_ingrediente              nome  fk_cod_tipo_medida
# 0                4  Farinha de trigo                   3
# 1                7    Fermento em pó                   3

# %% [markdown]
# ####b) Criar uma consulta para cada tipo de função data apresentada.

# %%
cursor.execute("""select data_hora_criacao, current_date as data_atual, current_date - data_hora_criacao as tempo_desde_pedido from pedido; """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select8 = pd.DataFrame(data=data,columns = colunas) 

select8
# Out:
#     data_hora_criacao  data_atual tempo_desde_pedido
# 0 2022-05-17 10:11:00  2022-06-25   38 days 13:49:00
# 1 2022-05-18 10:11:00  2022-06-25   37 days 13:49:00
# 2 2022-05-19 10:11:00  2022-06-25   36 days 13:49:00
# 3 2022-05-20 10:11:00  2022-06-25   35 days 13:49:00
# 4 2022-05-21 10:11:00  2022-06-25   34 days 13:49:00

# %%
cursor.execute("""select data_hora_criacao, now() as data_atual, now() - data_hora_criacao as tempo_desde_pedido from pedido;  """)

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select9 = pd.DataFrame(data=data,columns = colunas) 

select9
# Out:
#     data_hora_criacao                       data_atual      tempo_desde_pedido
# 0 2022-05-17 10:11:00 2022-06-25 20:51:08.945424+00:00 39 days 10:40:08.945424
# 1 2022-05-18 10:11:00 2022-06-25 20:51:08.945424+00:00 38 days 10:40:08.945424
# 2 2022-05-19 10:11:00 2022-06-25 20:51:08.945424+00:00 37 days 10:40:08.945424
# 3 2022-05-20 10:11:00 2022-06-25 20:51:08.945424+00:00 36 days 10:40:08.945424
# 4 2022-05-21 10:11:00 2022-06-25 20:51:08.945424+00:00 35 days 10:40:08.945424

# %%
cursor.execute("""select data_hora_criacao, now() as data_atual, age(data_hora_criacao) from pedido;""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select10 = pd.DataFrame(data=data,columns = colunas) 

select10
# Out:
#     data_hora_criacao                       data_atual              age
# 0 2022-05-17 10:11:00 2022-06-25 20:51:08.945424+00:00 37 days 13:49:00
# 1 2022-05-18 10:11:00 2022-06-25 20:51:08.945424+00:00 36 days 13:49:00
# 2 2022-05-19 10:11:00 2022-06-25 20:51:08.945424+00:00 35 days 13:49:00
# 3 2022-05-20 10:11:00 2022-06-25 20:51:08.945424+00:00 34 days 13:49:00
# 4 2022-05-21 10:11:00 2022-06-25 20:51:08.945424+00:00 33 days 13:49:00

# %%
cursor.execute("""select data_hora_entrega_prevista, now() as data_hora_agora, age(data_hora_entrega_prevista) as tempo_entrega_atrasada from pedido;""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select11 = pd.DataFrame(data=data,columns = colunas) 

select11
# Out:
#   data_hora_entrega_prevista                  data_hora_agora  \
# 0        2022-05-21 10:11:00 2022-06-25 20:51:08.945424+00:00
# 1        2022-05-22 10:11:00 2022-06-25 20:51:08.945424+00:00
# 2        2022-05-23 10:11:00 2022-06-25 20:51:08.945424+00:00
# 3        2022-05-24 10:11:00 2022-06-25 20:51:08.945424+00:00
# 4        2022-05-25 10:11:00 2022-06-25 20:51:08.945424+00:00
#
#   tempo_entrega_atrasada
# 0       33 days 13:49:00
# 1       32 days 13:49:00
# 2       31 days 13:49:00
# 3       30 days 13:49:00
# 4       30 days 13:49:00

# %%
cursor.execute("""select cod_pedido, data_hora_entrega_prevista, extract('day' from data_hora_entrega_prevista) as dia_entregas from pedido;""")

data = cursor.fetchall()

colunas = []

for col in cursor.description:
  colunas.append(col[0])

select12 = pd.DataFrame(data=data,columns = colunas) 

select12
# Out:
#    cod_pedido data_hora_entrega_prevista  dia_entregas
# 0           1        2022-05-21 10:11:00          21.0
# 1           2        2022-05-22 10:11:00          22.0
# 2           3        2022-05-23 10:11:00          23.0
# 3           4        2022-05-24 10:11:00          24.0
# 4           5        2022-05-25 10:11:00          25.0

# %%
conexao.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a86eff45937f> in <module>()
# ----> 1 conexao.close()
#
# NameError: name 'conexao' is not defined
