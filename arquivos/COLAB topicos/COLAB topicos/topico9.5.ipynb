# %%
import psycopg2
import pandas as pd

conexao = psycopg2.connect(host="kesavan.db.elephantsql.com", database="cjwdogrw", user="cjwdogrw", password="acihzKCpPs16aX1MGNmlYqY1OV--19Q6")
cursor = conexao.cursor()

# %%
cursor.execute("""delete from cliente where cod_cliente > 6""")

# %%
cursor.execute("""delete from telefone where cod_telefone = 7;""")

# %%
cursor.execute("""delete cascade from cliente where cod_cliente = 9;""")

# %%
cursor.execute("""update produto 
                  set preco = 70
                  where cod_produto = 5;""")

# %%
cursor.execute("""update telefone 
                  set descricao = '21 99555-4596'
                  where cod_telefone = 6;""")

# %%
cursor.execute("""update tipo_medida 
                  set descricao = 'Porção'
                  where cod_tipo_medida = 1;""")

# %%
conexao.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a86eff45937f> in <module>()
# ----> 1 conexao.close()
#
# NameError: name 'conexao' is not defined
